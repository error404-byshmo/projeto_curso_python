# %% [markdown]
# ### Módulo 1: Introdução à Programação em Python
#
# ### 1. Bem-vindos!
# Python é uma linguagem poderosa e fácil de aprender, muito usada em diversas áreas. Esta plataforma utiliza **Notebooks** para combinar teoria (células de texto) e prática (células de código) no mesmo ambiente.

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# ### 2. Células e Execução
# Um Notebook é formado por células de Markdown (como esta) e células de Código.
# Para executar o código de uma célula, selecione-a e pressione `Shift + Enter`.

# %%
# Exemplo: Use a função print() para mostrar uma mensagem na tela
print("Olá, Mundo!")

# %% [markdown]
# ### 3. Primeiro Desafio
# #### Exercício 1
# Na célula abaixo, use o comando `print()` para mostrar seu nome completo.

# %%
# EXERCÍCIO 1: Digite seu nome completo aqui
print("...")

# Teste de assertiva (Confirme visualmente)

# %% [markdown]
# ---
# **Módulo 1 Concluído!** Prossiga para o Módulo 2.
